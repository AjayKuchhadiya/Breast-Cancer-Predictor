# %%
# diagnosis - Tumors can be benign (noncancerous) or malignant (cancerous).
# Benign tumors tend to grow slowly and do not spread. Malignant tumors can grow rapidly, 
# invade and destroy nearby normal tissues, and spread throughout the body.

# %%
# Reading the data-set to perform EDA
import numpy as np
import pandas as pd
data_location = r"C:\Users\Owner\Desktop\breast_cancer_ml_project\BreastCancer0.csv"
X = pd.read_csv(data_location)

# %% [markdown]
# # Exploratory Data Analysis

# %%
X.shape
# Out:
# (569, 33)

# %%
X.head()
# Out:
#          id diagnosis  radius_mean  texture_mean    perimeter_mean  area_mean  \
# 0    842302         M          NaN         10.38  Greater than 120        NaN
# 1    842517         M        20.57         17.77  Greater than 120     1326.0
# 2  84300903         M        19.69         21.25  Greater than 120     1203.0
# 3  84348301         M        11.42         20.38      Less than 90      386.1
# 4  84358402         M        20.29         14.34  Greater than 120     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
X.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean      perimeter_mean  \
# 564  926424         M        21.56         22.39    Greater than 120
# 565  926682         M        20.13         28.25    Greater than 120
# 566  926954         M        16.60         28.08  Between 90 and 120
# 567  927241         M        20.60         29.33    Greater than 120
# 568   92751         B         7.76         24.54        Less than 90
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 564     1479.0          0.11100           0.11590         0.24390
# 565     1261.0          0.09780           0.10340         0.14400
# 566      858.1          0.08455           0.10230         0.09251
# 567     1265.0          0.11780           0.27700         0.35140
# 568      181.0          0.05263           0.04362         0.00000
#
#      concave points_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 564              0.13890  ...          26.40           166.10      2027.0
# ...

# %%
pd.set_option('display.max_columns', len(X.columns))

# %%
X.describe()  # Statistical overview of the dataset
# Out:
#                  id  radius_mean  texture_mean    area_mean  smoothness_mean  \
# count  5.690000e+02   544.000000    569.000000   550.000000       569.000000
# mean   3.037183e+07    14.105605     19.289649   652.551636         0.096360
# std    1.250206e+08     3.494799      4.301036   347.064675         0.014064
# min    8.670000e+03     6.981000      9.710000   143.500000         0.052630
# 25%    8.692180e+05    11.707500     16.170000   420.300000         0.086370
# 50%    9.060240e+05    13.375000     18.840000   548.750000         0.095870
# 75%    8.813129e+06    15.757500     21.800000   782.200000         0.105300
# max    9.113205e+08    28.110000     39.280000  2501.000000         0.163400
#
#        compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# count        569.000000      569.000000           569.000000     569.000000
# mean           0.104341        0.088799             0.048919       0.181162
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              544 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    object
#  5   area_mean                550 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
X.isnull().any()
# Out:
# id                         False
# diagnosis                  False
# radius_mean                 True
# texture_mean               False
# perimeter_mean             False
# area_mean                   True
# smoothness_mean            False
# compactness_mean           False
# concavity_mean             False
# concave points_mean        False
# symmetry_mean              False
# fractal_dimension_mean     False
# radius_se                  False
# texture_se                 False
# perimeter_se               False
# area_se                    False
# smoothness_se              False
# compactness_se             False
# concavity_se               False
# concave points_se          False
# symmetry_se                False
# fractal_dimension_se       False
# radius_worst               False
# texture_worst              False
# perimeter_worst            False
# area_worst                 False
# smoothness_worst           False
# compactness_worst          False
# ...

# %%
X.drop(X.iloc[:, [0,-1]], inplace=True, axis=1) # dropping useless columns

# %%
list(X.columns)
# Out:
# ['diagnosis',
#  'radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst']

# %%
X.head()
# Out:
#   diagnosis  radius_mean  texture_mean    perimeter_mean  area_mean  \
# 0         M          NaN         10.38  Greater than 120        NaN
# 1         M        20.57         17.77  Greater than 120     1326.0
# 2         M        19.69         21.25  Greater than 120     1203.0
# 3         M        11.42         20.38      Less than 90      386.1
# 4         M        20.29         14.34  Greater than 120     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  \
# ...

# %%
X.diagnosis.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
X.perimeter_mean.unique()
# Out:
# array(['Greater than 120', 'Less than 90', 'Between 90 and 120'],
#       dtype=object)

# %% [markdown]
# # Data visualization

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
X.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
plt.figure(figsize=(15,7))
plt.xlabel('Diagnosis', size = 15, color = 'r')
plt.ylabel('Count', size = 15, color = 'r')

sns.histplot(X.diagnosis)
plt.show()

# %%
X.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
# With the subplot() function you can draw multiple plots in one figure:
plt.figure(figsize=(40,10))
sns.set_style("dark")


#plot 1:

plt.subplot(1, 4, 1) #the figure has 1 row, 4 columns, and this plot is the first plot.
plt.xlabel('radius_mean', size = 15, color = 'r')
plt.ylabel('texture_mean', size = 15, color = 'r')
sns.scatterplot(x = X.radius_mean, y = X.texture_mean, hue =X.diagnosis )
plt.title('first', size = 15 , color = 'hotpink')

#plot 2:

# 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean'
plt.subplot(1, 4, 2) 
plt.xlabel('radius_mean', size = 15, color = 'r')
plt.ylabel('perimeter_mean', size = 15, color = 'r')
sns.scatterplot(x = X.radius_mean, y = X.perimeter_mean, hue =X.diagnosis )
plt.title('second', size = 15 , color = 'hotpink')

#plot 3:
plt.subplot(1, 4, 3)
plt.xlabel('radius_mean', size = 15, color = 'r')
plt.ylabel('concave points_mean', size = 15, color = 'r')
sns.scatterplot(x = X.radius_mean, y = X['concave points_mean'], hue =X.diagnosis )
plt.title('third', size = 15 , color = 'hotpink')

#plot 4:
plt.subplot(1, 4, 4)
plt.xlabel('radius_mean', size = 15, color = 'r')
plt.ylabel('area_mean', size = 15, color = 'r')
sns.scatterplot(x = X.radius_mean, y = X.area_mean, hue =X.diagnosis )
plt.title('fourth', size = 15 , color = 'hotpink')

plt.suptitle('Relationship beteween various parameters classifying breast cancer', size = 35, color = 'b')

plt.show()

# %%
X.diagnosis.replace('M', 1, inplace = True)
#
X.diagnosis.replace('B', 0, inplace = True)

# %% [markdown]
# #### Co-relation between feature columns

# %%
columns =  ['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean'] 

plt.figure(figsize=(10,5))
sns.set_style("dark")

sns.heatmap(X[columns].corr(), annot=True,center = 0, fmt='.1%',  linewidths=.5)
plt.show()

# %% [markdown]
# we can see a very low corelation bw fractal_dimension_mean and diagnosis.
# So, we can drop it from the feature column

# %% [markdown]
# #### Detecting outliers -

# %%
columns_updated =  [ 'radius_mean', 'texture_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean'] 
j = 1
for i in columns_updated[0:4]:
    sns.set_style("whitegrid")
    plt.figure(figsize=(10,30))
    sns.set_style("dark")
    plt.subplot(len(columns_updated),1, j)
    sns.boxplot(x = 'diagnosis', y = i, data = X,flierprops = dict(markerfacecolor = '0.50', markersize = 2))
    j = j + 1
    plt.show()

# %%
plt.figure(figsize=(10,10))
sns.set_style("dark")

X.boxplot(by ='diagnosis', column = columns_updated,flierprops = dict(markerfacecolor = '0.50', markersize = 2))
plt.show()

# %%
sns.swarmplot(x=X['diagnosis'],
              y=X['area_mean'])
# Out:
# C:\python37\lib\site-packages\seaborn\categorical.py:3540: UserWarning: 9.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot: xlabel='diagnosis', ylabel='area_mean'>
# C:\python37\lib\site-packages\seaborn\categorical.py:3540: UserWarning: 34.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
X.describe()
# Out:
#         diagnosis  radius_mean  texture_mean    area_mean  smoothness_mean  \
# count  569.000000   544.000000    569.000000   550.000000       569.000000
# mean     0.372583    14.105605     19.289649   652.551636         0.096360
# std      0.483918     3.494799      4.301036   347.064675         0.014064
# min      0.000000     6.981000      9.710000   143.500000         0.052630
# 25%      0.000000    11.707500     16.170000   420.300000         0.086370
# 50%      0.000000    13.375000     18.840000   548.750000         0.095870
# 75%      1.000000    15.757500     21.800000   782.200000         0.105300
# max      1.000000    28.110000     39.280000  2501.000000         0.163400
#
#        compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# count        569.000000      569.000000           569.000000     569.000000
# mean           0.104341        0.088799             0.048919       0.181162
# ...

# %% [markdown]
# # Training the Model

# %%
from sklearn.model_selection import train_test_split

# Obtain target and predictors
y = X.diagnosis         # target data

features = ['radius_mean', 'texture_mean',
        'area_mean', 'smoothness_mean', 'compactness_mean','perimeter_mean', 'concavity_mean',
        'concave points_mean', 'symmetry_mean']

X = X[features].copy()  # feature data

# Breaking off validation set from training data
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2,
                                                      random_state=0)

# %%
X_train.head()
# Out:
#      radius_mean  texture_mean  area_mean  smoothness_mean  compactness_mean  \
# 338        10.05         17.53      310.8          0.10070           0.07326
# 427        10.80         21.98      359.9          0.08801           0.05743
# 406        16.14         14.86      800.0          0.09495           0.08501
# 96         12.18         17.84      451.1          0.10450           0.07057
# 490        12.25         22.44      466.5          0.08192           0.05200
#
#          perimeter_mean  concavity_mean  concave points_mean  symmetry_mean
# 338        Less than 90         0.02511              0.01775         0.1890
# 427        Less than 90         0.03614              0.01404         0.2016
# 406  Between 90 and 120         0.05500              0.04528         0.1735
# 96         Less than 90         0.02490              0.02941         0.1900
# 490        Less than 90         0.01714              0.01261         0.1544

# %% [markdown]
# ### working with categorical values

# %%
# Replacing catigorical values from the dataset 

low_cardinality_cols = [cname for cname in X_train.columns if X_train[cname].dtype == 'object'
                        ]

# %%
from sklearn.preprocessing import OrdinalEncoder

ordinal_encoder = OrdinalEncoder()
X_train[low_cardinality_cols] = ordinal_encoder.fit_transform(X_train[low_cardinality_cols])
X_valid[low_cardinality_cols] = ordinal_encoder.transform(X_valid[low_cardinality_cols])

# %%
X_train.head()
# Out:
#      radius_mean  texture_mean  area_mean  smoothness_mean  compactness_mean  \
# 338        10.05         17.53      310.8          0.10070           0.07326
# 427        10.80         21.98      359.9          0.08801           0.05743
# 406        16.14         14.86      800.0          0.09495           0.08501
# 96         12.18         17.84      451.1          0.10450           0.07057
# 490        12.25         22.44      466.5          0.08192           0.05200
#
#      perimeter_mean  concavity_mean  concave points_mean  symmetry_mean
# 338             2.0         0.02511              0.01775         0.1890
# 427             2.0         0.03614              0.01404         0.2016
# 406             0.0         0.05500              0.04528         0.1735
# 96              2.0         0.02490              0.02941         0.1900
# 490             2.0         0.01714              0.01261         0.1544

# %% [markdown]
# ### removing null values

# %%
from sklearn.impute import SimpleImputer

# imputation
my_impute = SimpleImputer(strategy = 'mean') # Imputing mean inplace of null values
imputed_X_train = pd.DataFrame(my_impute.fit_transform(X_train))
imputed_X_valid =pd.DataFrame(my_impute.transform(X_valid))

# imputation removed column names; put them back
imputed_X_train.columns = X_train.columns
imputed_X_valid.columns = X_valid.columns

# %%
imputed_X_train.isnull().any()  # Null values removed
# Out:
# radius_mean            False
# texture_mean           False
# area_mean              False
# smoothness_mean        False
# compactness_mean       False
# perimeter_mean         False
# concavity_mean         False
# concave points_mean    False
# symmetry_mean          False
# dtype: bool

# %%
imputed_X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 455 entries, 0 to 454
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   radius_mean          455 non-null    float64
#  1   texture_mean         455 non-null    float64
#  2   area_mean            455 non-null    float64
#  3   smoothness_mean      455 non-null    float64
#  4   compactness_mean     455 non-null    float64
#  5   perimeter_mean       455 non-null    float64
#  6   concavity_mean       455 non-null    float64
#  7   concave points_mean  455 non-null    float64
#  8   symmetry_mean        455 non-null    float64
# dtypes: float64(9)
# memory usage: 32.1 KB

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
final_model = RandomForestRegressor()
final_model.fit(imputed_X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
predictions = final_model.predict(imputed_X_valid)

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(predictions, y_valid)
print('MAE value is :',mae)
# Out:
# MAE value is : 0.08622807017543858

# %%
# 0.0882 with fractal
# 0.0853 without fractal

# %% [markdown]
# ### model validation

# %%
from sklearn.model_selection import KFold, cross_val_score

# %%
k_folds = KFold(n_splits = 5)

scores = cross_val_score(final_model, imputed_X_train, y_train, cv = k_folds)

# %%
print("Cross Validation Scores: ", scores)
print("Average CV Score: ", scores.mean())
print("Number of CV Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.68205167 0.82160022 0.67396362 0.83951369 0.79452843]
# Average CV Score:  0.7623315261205913
# Number of CV Scores used in Average:  5

# %% [markdown]
# #### Now that the model is prepared we can deploy it to production using some web APIs, such as FastAPI framework
